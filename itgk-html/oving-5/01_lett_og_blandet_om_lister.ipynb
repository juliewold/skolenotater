# %% [markdown]
# <nav class="navbar navbar-default">
#   <div class="container-fluid">
#     <div class="navbar-header">
#       <a class="navbar-brand" href="_Oving5.ipynb">Øving 5</a>
#     </div>
#     <ul class="nav navbar-nav">
#       <li><a href="00_generelt_om_lister.ipynb">Generelt om lister</a></li>
#       <li class="active"><a href="01_lett_og_blandet_om_lister.ipynb">Lett og blandet om lister</a></li>
#       <li><a href="02_kodeforstaelse.ipynb">Kodeforståelse</a></li>
#       <li><a href="03_vektorer.ipynb">Vektorer</a></li>
#       <li><a href="04_lister_og_lokker.ipynb">Lister og løkker</a></li>
#       <li><a href="05_teoridelen_pa_eksamen.ipynb">Teoridelen på eksamen</a></li>
#       <li><a href="06_gangetabell_og_lister.ipynb">Gangetabell og lister</a></li>
#       <li><a href="07_lotto.ipynb">Lotto</a></li>
#       <li><a href="08_tannfeen.ipynb">Tannfeen</a></li>
#       <li><a href="09_chattebot.ipynb">Chattebot</a></li>
#       <li><a href="10_matriseaddisjon.ipynb">Matriseaddisjon</a></li>
#       <li><a href="11_list_comprehensions.ipynb">List Comprehensions</a></li>
#     </ul>
#   </div>
# </nav>
#
# # Lett og blandet om lister
#
# **Læringsmål:**
#
# - Lister
#
# **Starting Out with Python:**
#
# - Kap. 7.1
# - Kap. 7.2
# - Kap. 7.3
#
# Les om innebygde funksjoner i Python [her](https://docs.python.org/3/library/functions.html), og mer om lister i Python [her](https://docs.python.org/3/tutorial/datastructures.html). Merk at kun noen av disse er pensum, og det vil bli utdelt et nokså utfyllende "formelark" på eksamen.

# %% [markdown]
# ## a)

# %% [markdown]
# Lag en funksjon **is_six_at_edge()**, som tar inn en liste med heltall som parameter og returnerer **True** dersom **6** er det første eller det siste elementet i listen. Funksjonen returnerer ellers **False**.
# NB! Funksjonen skal også returnere True hvis lista starter **og** slutter på 6.
#
# Eksempel på kjøring:
#
# ```python
# print(is_six_at_edge([1, 2, 3, 4, 5, 6]))
# True
# >>>
# print(is_six_at_edge([1, 2, 3, 4, 5, 6, 7]))
# False
# ```
#
# ***Skriv koden din i boksen under.***

# %%
# Min kode
def is_six_at_edge(liste):
    if liste[0] == 6 or liste[-1] == 6:
        # liste[0] er det første elementet i lista
        # liste[-1] er det siste elementet i lista
        return True
    else:
        return False
print(is_six_at_edge([1, 2, 3, 4, 5, 6]))
print(is_six_at_edge([1, 2, 3, 4, 5, 6, 7]))
# Out:
# True
# False

# %% [markdown]
# ### Sum og lengde av en liste

# %% [markdown]
# `sum(listen)` returnerer den totale summen av alle elementene i listen, for eksempel `sum([1, 2, 3, 4])` $= 1 + 2 + 3 + 4 = 10$.
#
# `len(listen)` returnerer antall elementer i listen, for eksempel `len([1, 2, 3, 4])` $= 4$.

# %% [markdown]
# ## b)

# %% [markdown]
# Bruk den innebygde funksjonen [`sum()`](https://docs.python.org/3/library/functions.html#sum), samt `len()` for å lage en funksjon `average()` som tar inn en liste med tall som parameter og returnerer gjennomsnittsverdien til tallene i listen. Du kan anta at listen ikke er tom.
#
# Eksempel på kjøring:
#
# ```python
# print(average([1, 3, 5, 7, 9, 11]))
# 6
# ```
#
# ***Skriv koden din i boksen under.***

# %%
# Min kode
def average(tall):
    if tall == []: # Om lista er tom
        return 0   # Returner 0
    return sum(tall) / len(tall) # Gjennomsnittsverdien til tallene i listen

print(average([1, 3, 5, 7, 9, 11])) # Tester med liste med tall
print(average([]))                  # Tester med tom liste
# Out:
# 6.0
# 0

# %% [markdown]
# **Bonus:** Du trenger ikke å gjøre denne oppgaven for å få godkjent oppgaven. Endre koden din over slik at den også fungerer for tomme lister. I så fall skal funksjonen returnere `0`.

# %% [markdown]
# ## c)

# %% [markdown]
# Bruk den innebygde metoden [`.sort()`](https://docs.python.org/3/howto/sorting.html) for å lage en funksjon `median()` som tar inn en liste og finner medianen av listen og returnerer den. Husk at medianen er det midterste elementet i en sortert rekkefølge av listens elementer.
#
# *NB! Du kan anta at det er et oddetall antall elementer i listen!*
#
# Eksempel på kjøring:
#
# ```python
# >>> print(median([1, 2, 4, 5, 7, 9, 10]))
# 5
# >>> print(median([1, 4, 2, 5, 3]))
# 3
# ```
#
# ***Skriv koden din i boksen under.***

# %%
# Min kode
def median(my_list):
    my_list.sort() # Sorterer lista
    midt_index = len(my_list) // 2 # Heltallsdivisjon for å finne indeksen til det miderste tallet
    return my_list[midt_index]

print(median([1, 2, 4, 5, 7, 9, 10]))
print(median([1, 4, 2, 5, 3]))
# Out:
# 5
# 3

# %% [markdown]
# ### Hint

# %% [markdown]
# Ved å skrive `my_list.sort()` sorterer du elementene i listen **my_list**

# %% [markdown]
# ## d) (Frivillig)

# %% [markdown]
# Endre koden i funksjonen `median()` slik at den også fungerer for lister med et partall antall elementer. I dette tilfellet skal funksjonen returnere gjennomsnittet av de to midterste elementene i den sorterte listen.
#
# I tillegg kan du definere medianen til en tom liste som `0`.

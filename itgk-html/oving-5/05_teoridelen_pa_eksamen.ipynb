# %% [markdown]
# <nav class="navbar navbar-default">
#   <div class="container-fluid">
#     <div class="navbar-header">
#       <a class="navbar-brand" href="_Oving5.ipynb">Øving 5</a>
#     </div>
#     <ul class="nav navbar-nav">
#       <li><a href="00_generelt_om_lister.ipynb">Generelt om lister</a></li>
#       <li><a href="01_lett_og_blandet_om_lister.ipynb">Lett og blandet om lister</a></li>
#       <li><a href="02_kodeforstaelse.ipynb">Kodeforståelse</a></li>
#       <li><a href="03_vektorer.ipynb">Vektorer</a></li>
#       <li><a href="04_lister_og_lokker.ipynb">Lister og løkker</a></li>
#       <li class="active"><a href="05_teoridelen_pa_eksamen.ipynb">Teoridelen på eksamen</a></li>
#       <li><a href="06_gangetabell_og_lister.ipynb">Gangetabell og lister</a></li>
#       <li><a href="07_lotto.ipynb">Lotto</a></li>
#       <li><a href="08_tannfeen.ipynb">Tannfeen</a></li>
#       <li><a href="09_chattebot.ipynb">Chattebot</a></li>
#       <li><a href="10_matriseaddisjon.ipynb">Matriseaddisjon</a></li>
#       <li><a href="11_list_comprehensions.ipynb">List Comprehensions</a></li>
#     </ul>
#   </div>
# </nav>
#
# # Teoridelen på eksamen
#
# **Læringsmål:**
#
# - Lister
# - Funksjoner
#
# **Starting Out with Python:**
#
# - Kap. 7
#
# I denne oppgaven skal du sammenligne to lister og studere hvor like de er hverandre.
#
# 25% av eksamen er flervalgsoppgaver, og her skal vi anta at det alltid vil være 20 oppgaver. Riktige svar for oppgavene er som følger:

# %% [markdown]
# | Riktige svar |      |      |      |
# |-------------:|-----:|-----:|-----:|
# |          1.A |  6.A | 11.D | 16.A |
# |          2.C |  7.B | 12.A | 17.B |
# |          3.B |  8.A | 13.C | 18.A |
# |          4.D |  9.C | 14.C | 19.C |
# |          5.A | 10.A | 15.B | 20.D |

# %% [markdown]
# ## a)

# %% [markdown]
# Lag en liste *fasit* som inneholder de korrekte svarene.
#
# ***Skriv svaret ditt i boksen under.***

# %%
fasit = ["1.A", "2.C", "3.B", "4.D", "5.A", "6.A", "7.B", "8.A", "9.C", "10.A", "11.D", "12.A", 
         "13.C", "14.C", "15.B", "16.A", "17.B", "18.A", "19.C", "20.D"]

# %% [markdown]
# ## b)

# %% [markdown]
# Lag en funksjon `sjekk_svar` som tar inn studentens_svar som argument. studentens_svar er en liste som inneholder en students svar på oppgavene. Ved å sammenligne studenten sine svar med de riktige svarene, skal funksjonen returnere hvor mange prosent av oppgavene studenten klarte.
#
# Eksempel på kjøring:
#
# ```python
# print(sjekk_svar(["A", "C", "B", "D", "A", "A", "B", "A", "C", "A", "D", "A", "C", "C", "B", "A", "B", "A", "A", "C"]))  # Gir 90% riktig
# print(sjekk_svar(fasit))  # Gir 100% riktig
# ```
#
# ***Skriv svaret ditt i boksen under.***

# %%
def sjekk_svar(svar): # Definerer en funksjon som tar inn en liste med studentens svar
    riktige = 0 # Teller for hvor mange riktige svar studenten har fått
    for i in range(len(fasit)):
        if svar[i] == fasit[i].split(".")[1]:
            # fasit[i] ser f.eks. slik ut: "1.A"
            # split(".") deler teksten i to deler: ["1", "A"]
            # [1] henter ut selve bokstaven (A, B, C eller D)
            riktige += 1 # Om svaret er riktig øker tellevariablen med 1
    prosent = (riktige / len(fasit)) * 100 # Prosentregning
    return prosent

# %% [markdown]
# Har du gjort det på riktig måte skal koden under gi 20% riktig. Trykk på blokka under og trykk `ctrl + enter` for å kjøre den.

# %%
print(sjekk_svar(["B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B", "B"]))
# Out:
# 20.0

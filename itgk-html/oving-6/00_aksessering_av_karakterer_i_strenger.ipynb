# %% [markdown]
# <nav class="navbar navbar-default">
#   <div class="container-fluid">
#     <div class="navbar-header">
#       <a class="navbar-brand" href="_Oving6.ipynb">Øving 6</a>
#     </div>
#     <ul class="nav navbar-nav">
#       <li class="active"><a href="00_aksessering_av_karakterer_i_strenger.ipynb">Aksessering av karakterer i strenger</a></li>
#       <li><a href="01_strenger_og_konkatinering.ipynb">Strenger og konkatinering</a></li>
#       <li><a href="02_slicing_av_strenger.ipynb">Slicing av strenger</a></li>
#       <li><a href="03_tekstbehandling.ipynb">Tekstbehandling</a></li>
#       <li><a href="04_strenghandtering.ipynb">Strenghåndtering</a></li>
#       <li><a href="05_innebygde_funksjoner_og_lister.ipynb">Innebygde funksjoner og lister</a></li>
#       <li><a href="06_fjesboka.ipynb">Fjesboka</a></li>
#       <li><a href="07_akkorder_og_toner.ipynb">Akkorder og toner</a></li>
#       <li><a href="08_ideel_gasslov.ipynb">Ideel gasslov</a></li>
#       <li><a href="09_sammenhengende_tallrekke.ipynb">Sammenhengende tallrekke</a></li>
#       <li><a href="10_intro_til_numpy_arrays.ipynb">Intro til NumPy-arrays</a></li>
#       <li><a href="11_sortering.ipynb">Sortering</a></li>
#       <li><a href="12_strengmanipulasjon.ipynb">Strengmanipulasjon</a></li>
#       <li><a href="13_kryptering.ipynb">Kryptering</a></li>
#       <li><a href="14_litt_sjakk.ipynb">Litt sjakk</a></li>
#     </ul>
#   </div>
# </nav>
#
# # Aksessering av karakterer i strenger
#
# **Læringsmål:**
#
# - Strenger
# - Funksjoner
#
# **Starting Out with Python:**
#
# - Kap. 8.1

# %% [markdown]
# Denne oppgaven handler om hvordan man får tak i og returnerer karakterer i en streng.

# %% [markdown]
# ## Generelt om aksessering

# %% [markdown]
# ### Å iterere over strenger
#
# Man kan lett iterere over en streng ved hjelp av en for-løkke. Den generelle formen for dette er:

# %%
for character in string:
    # Do something

# %% [markdown]
# For hver iterasjon vil character-variabelen referere til en karakter i string, og den vil starte med å referere til den første karakteren. Vi sier at løkken itererer over strengen. Prøv å kjør koden under.

# %%
name = "Bob Bernt"

for ch in name:
    print(ch)
# Out:
# B
# o
# b
#
# B
# e
# r
# n
# t

# %% [markdown]
# ### Indeks
#
# Å iterere over en streng med for-løkke er en måte å aksessere hver enkelt karakter i en streng. En annen måte for å aksessere karakterene i en streng på er å bruke indeks. Alle karakterene i en streng har hver sin indeks knyttet til deres plassering i strengen:
#
# ![img](../../Resources/Images/streng-eksempel.png)
#
# Som man kan se på bildet, starter indekseringen med 0, akkurat som for lister. For å få tak i en av karakterene og tilordne den til en variabel, skriver man `ch = my_string[3]`, dette vil tilordne ch til "e".
#
# Hver karakter i strengen kan aksesseres vha. to tall: et positivt og et negativt. Om man skal ha tak i siste karakter i strengen kan man enten bruke 12 eller -1 som indeks, dvs. både `ch = my_string [12]` og `ch = my_string[-1]` vil tilordne ch til "d". Tilsvarende vil 1 og -12 begge være indekser for "o" i my_string.

# %%
# Prøv å kjøre koden
my_string = "Roses are red"

for i in range(5):
    print(my_string[i])

for j in range(-7, 0, 1):
    print(my_string[j])
# Out:
# R
# o
# s
# e
# s
# a
# r
# e
#
# r
# e
# d

# %% [markdown]
# ## a)

# %% [markdown]
# Skriv en funksjon som tar inn en streng, itererer over denne, og skriver ut hver enkelt karakter til skjerm.
#
# **Eksempel på kjøring**:
#
# ```python
# # Argumentet er `Nilfgaard`
# N
# i
# l
# f
# g
# a
# a
# r
# d
# ```
#
# ***Skriv inn koden din i kodeblokken under:***

# %%
# Min kode
streng = "Nilfgaard"

for i in streng:
    print(i)
# Out:
# N
# i
# l
# f
# g
# a
# a
# r
# d

# %% [markdown]
# ## b)

# %% [markdown]
# Skriv en funksjon `third_letter(string)` som tar inn en streng og returnerer den tredje bokstaven i strengen. Om lengden til strengen ikke er stor nok, skal funksjonen returnere "q".
#
# ***Skriv inn koden din i kodeblokken under:***

# %%
# Min kode
def third_letter(string):
    if len(string) < 3:
        return "q"
    else:
        return string[2]

# %% [markdown]
# Dersom du har implementert funksjonen rett, sjekk om koden under gir forventet resultat:

# %%
print(third_letter("Temeria"))  # Skal gi "m"
print(third_letter("IT"))  # Skal printe ut "q"
# Out:
# m
# q

# %% [markdown]
# ## c)

# %% [markdown]
# Skriv en funksjon som tar inn en streng og returnerer største gyldige indeks, dvs. den største indeksen som ikke gir IndexError.
#
# **Eksempel på kjøring:**
#
# ```python
# # Argumentet er "The White Wolf"
# 13
#
# # Argumentet er "Redania"
# 6
# ```
#
# ***Skriv koden i kodeblokken under:***

# %%
# Min kode
def storste_gyldige_indeks(x):
    return len(x) - 1

print(storste_gyldige_indeks("The White Wolf"))
print(storste_gyldige_indeks("Redania"))
# Out:
# 13
# 6

# %% [markdown]
# <nav class="navbar navbar-default">
#   <div class="container-fluid">
#     <div class="navbar-header">
#       <a class="navbar-brand" href="_Oving6.ipynb">Øving 6</a>
#     </div>
#     <ul class="nav navbar-nav">
#       <li><a href="00_aksessering_av_karakterer_i_strenger.ipynb">Aksessering av karakterer i strenger</a></li>
#       <li><a href="01_strenger_og_konkatinering.ipynb">Strenger og konkatinering</a></li>
#       <li class="active"><a href="02_slicing_av_strenger.ipynb">Slicing av strenger</a></li>
#       <li><a href="03_tekstbehandling.ipynb">Tekstbehandling</a></li>
#       <li><a href="04_strenghandtering.ipynb">Strenghåndtering</a></li>
#       <li><a href="05_innebygde_funksjoner_og_lister.ipynb">Innebygde funksjoner og lister</a></li>
#       <li><a href="06_fjesboka.ipynb">Fjesboka</a></li>
#       <li><a href="07_akkorder_og_toner.ipynb">Akkorder og toner</a></li>
#       <li><a href="08_ideel_gasslov.ipynb">Ideel gasslov</a></li>
#       <li><a href="09_sammenhengende_tallrekke.ipynb">Sammenhengende tallrekke</a></li>
#       <li><a href="10_intro_til_numpy_arrays.ipynb">Intro til NumPy-arrays</a></li>
#       <li><a href="11_sortering.ipynb">Sortering</a></li>
#       <li><a href="12_strengmanipulasjon.ipynb">Strengmanipulasjon</a></li>
#       <li><a href="13_kryptering.ipynb">Kryptering</a></li>
#       <li><a href="14_litt_sjakk.ipynb">Litt sjakk</a></li>
#     </ul>
#   </div>
# </nav>
#
# # Slicing av strenger
#
# **Læringsmål:**
#
# - Strenger
# - Funksjoner
# - Lister
#
# **Starting Out with Python:**
#
# - Kap. 8.2

# %% [markdown]
# ## Kort om slicing

# %% [markdown]
# Slicing kan brukes til å velge ut en del av en streng. Formatet for dette er: **string[start : slutt : steg]**.
#
# - Den nye strengen vil starte på karakteren start-indeksen tilsvarer. Om start ikke er spesifisert, antas indeks 0.
# - Slutt-indeksen spesifiserer hvilke karakter den nye strengen skal stoppe på. Akkrat som med range()-funksjonen, så er karakteren på slutt-indeksen ikke inkludert. Om slutt ikke er spesifisert, antas indeks len(string).
# - Steg spesifiserer hvor mange indekser man øker med for hver karakter. Om steg ikke er spesifisert antas steg = 1, som betyr at hver indeks skal velges. Hvis steg = 2 skal annenhver indeks velges.
#
# **Eksempel:**

# %%
streng = "One ring to rule them all"
print(streng[:3])  # Samme som streng[0:3]
print(streng[12:16])
print(streng[12:])  # Samme som streng[12:len(streng)] og streng[12:25]
print(streng[1::9])
# Out:
# One
# rule
# rule them all
# noe

# %% [markdown]
# ### a)

# %% [markdown]
# Skriv en funksjon som tar inn en streng som argument, og returnerer en ny streng bestående av hver fjerde karakter i argumentet.
#
# **Eksempel:**
#
# ```python
# # streng = "I Was Told There'd Be Cake"
# -> Islh'ek
# ```
#
# ***Skriv koden din i kodeblokken under***

# %%
# Min kode
def fjerde_karakter(streng):
    ny_streng = streng[::4]
    return ny_streng

print(fjerde_karakter("I Was Told There'd Be Cake"))
# Out:
# Islh'ek

# %% [markdown]
# ### b)

# %% [markdown]
# Skriv en funksjon som tar inn en liste med strenger, itererer gjennom denne, og returnerer en ny streng bestående av de to siste karakterene i strengene i listen.
#
# **Eksempel:**
#
# ```python
# # liste = ["banan", "propan", "Westerosi"]
# -> anansi
# ```
#
# ***Skriv koden din i kodeblokken under***

# %%
# Min kode
def to_siste_karakterer(liste):
    ny_streng = ""
    for i in liste:
        if len(i) >= 2:
            ny_streng += i[-2:]
    return ny_streng

print(to_siste_karakterer(["banan", "propan", "Westerosi"]))
# Out:
# anansi

# %% [markdown]
# ### c)

# %% [markdown]
# Under følger tre kodesnutter, der to inneholder en feil hver, og den siste er rett. Hvilken kode er korrekt? Finn feilen i de to andre.

# %% [markdown]
# ```python
# # Kodesnutt 1
# streng = "I Want Cake"
# streng[7:] = "Cupcake"
# print(streng)
#
# # Kodesnutt 2
# streng = "I Want Cake"
# streng = streng[-4:100:]
# print(streng)
#
# # Kodesnutt 3
# streng = "I Want Cake"
# streng = streng[]
# print(streng)
# ```

# %% [markdown]
# Dobbeltklikk på teksten under og skriv svaret ditt i boksen.

# %% [markdown]
# **Svar:**
#
# Kodesnutt 1:
# Feil
# Strenger kan ikke endres på direkte
#
# Kodesnutt 2:
# Korrekt
# Bruker slicing riktig. Den tar alt fra fjerde tegn fra slutten og utover, her blir det "Cake".
# Selv om 100 er større enn lengden, gjør det ingenting — Python stopper automatisk på slutten.
#
# Kodesnutt 3:
# Feil. Slicing må ha minst en kolon i seg for å fungere.
